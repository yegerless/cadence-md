# %%
import sys
from pathlib import Path

from dotenv import load_dotenv

_cwd = Path.cwd()
_project_root = _cwd if (_cwd / "cadence_md").is_dir() else _cwd.parent
load_dotenv(_project_root / ".env.dev", override=True)


root_path = _project_root

cadence_path = root_path / "cadence_md"

if str(root_path) not in sys.path:
    sys.path.append(str(root_path))
if str(cadence_path) not in sys.path:
    sys.path.append(str(cadence_path))

from cadence_md.app.embedder import get_embedder  # noqa: E402
from cadence_md.app.llm import get_llm  # noqa: E402
from cadence_md.app.qdrant import QdrantManager  # noqa: E402
from cadence_md.app.rag import RAGPipeline  # noqa: E402
from cadence_md.app.reranker import get_reranker  # noqa: E402
from cadence_md.app.settings import settings  # noqa: E402

# %%
embedder = get_embedder(
    model=settings.embedding_cfg.model_name,
    normalize=settings.embedding_cfg.normalize_embeddings,
    return_score=settings.embedding_cfg.return_score,
    base_url=settings.MODEL_INFERENCE_BASE_URL,
    api_key=settings.MODEL_INFERENCE_API_KEY,
)
reranker = get_reranker(
    model=settings.rag_config.reranker.model_name,
    top_k=settings.rag_config.reranker.top_k,
    return_score=settings.rag_config.reranker.return_score,
    base_url=settings.MODEL_INFERENCE_BASE_URL,
    api_key=settings.MODEL_INFERENCE_API_KEY,
    timeout_s=settings.rag_config.reranker.timeout_seconds,
    max_retries_on_rate_limit=settings.rag_config.reranker.max_retries_on_rate_limit,
)
qdrant_manager = QdrantManager(
    data_dir=settings.rag_config.qdrant_config.data_dir,
    chunking_cfg=settings.rag_config.chunking,
    retrieval_cfg=settings.rag_config.retrieval,
    qdrant_cfg=settings.rag_config.qdrant_config,
    url=settings.QDRANT_BASE_URL,
    api_key=settings.QDRANT_API_KEY,
    https=settings.QDRANT_HTTPS,
    embedder=embedder,
    collection_name=settings.rag_config.qdrant_config.collection_name,
    uploading_batch_size=settings.rag_config.qdrant_config.uploading_batch_size,
    sparse_model=settings.rag_config.qdrant_config.sparse_model,
    search_mode=settings.rag_config.retrieval.search_mode,
    fusion_method=settings.rag_config.retrieval.fusion_method,
    sparse_top_k=settings.rag_config.retrieval.sparse_top_k,
    dense_top_k=settings.rag_config.retrieval.dense_top_k,
    hybrid_top_k=settings.rag_config.retrieval.hybrid_top_k,
)
qdrant_manager.setup_qdrant()
# Out:
# /Users/yegerless/projects/cadence-md/cadence_md/app/qdrant.py:27: UserWarning: Api key is used with an insecure connection.
#   self.qdrant_client = QdrantClient(
# Fetching 18 files: 100%|██████████| 18/18 [00:00<00:00, 19.78it/s]
# Using existing collection; FastEmbed BM25 is stateless
# Qdrant database is ready for working with RAG

# %%
llm = get_llm(
    model=settings.rag_config.llm.model_name,
    base_url=settings.MODEL_INFERENCE_BASE_URL,
    api_key=settings.MODEL_INFERENCE_API_KEY,
    temperature=settings.rag_config.llm.temperature,
    max_completion_tokens=settings.rag_config.llm.max_new_tokens,
    top_p=settings.rag_config.llm.top_p,
    streaming=settings.rag_config.llm.streaming,
)

# %%
rag_pipeline = RAGPipeline(llm, qdrant_manager, reranker=reranker)

test_queries = [
    "Какие антигипертензивные препараты рекомендуются в качестве первой линии "
    "для пациента с впервые диагностированной артериальной гипертензией II степени "
    "и отсутствием сопутствующих заболеваний?",
    "Какие диагностические критерии используются для подтверждения диагноза "
    "сахарного диабета 2 типа? Какие значения глюкозы натощак и HbA1c считаются "
    "диагностическими?",
    "Пациент 65 лет с внебольничной пневмонией, без серьёзных сопутствующих "
    "заболеваний, поступил в амбулаторное отделение. Какие антибиотики "
    "рекомендуются для начальной терапии?",
]

# Run RAG for each query
for query in test_queries:
    result = rag_pipeline.run(query)

    print(f"QUERY: {result['query']}")
    print()
    ranked_docs = result.get("ranked_docs", [])
    print(f"\nRETRIEVED DOCUMENTS ({len(ranked_docs)}):")
    for i, rd in enumerate(ranked_docs, 1):
        doc = rd["doc"]
        final_score = rd.get("final_score")
        score_str = f"{final_score:.4f}" if isinstance(final_score, (int, float)) else "n/a"
        print(f"\n{i}. {doc.metadata.get('filename', 'unknown')} (score: {score_str})")
        print(f"   {doc.page_content[:200]}...")
        print()

    print("ANSWER:")
    print(result["answer"])
    print("\n" + "=" * 60 + "\n")
# Out:
# [GRAPH] Building LangGraph...
# ✓ Graph built successfully
# QUERY: Какие антигипертензивные препараты рекомендуются в качестве первой линии для пациента с впервые диагностированной артериальной гипертензией II степени и отсутствием сопутствующих заболеваний?
#
# [GRAPH] Building LangGraph...
# ✓ Graph built successfully
# [RETRIEVE] Query: Какие антигипертензивные препараты рекомендуются в качестве первой линии для пациента с впервые диагностированной артериальной гипертензией II степени и отсутствием сопутствующих заболеваний?
# Retrieved 20 documents
#   1. chronic_myeloid_leukemia.pdf
#   2. aortic_insufficiency.pdf
#   3. hypertrophic_cardiomyopathy.pdf
#   4. primary_adrenal_deficiency.pdf
#   5. mucopolysaccharidosis_type_2.pdf
#   6. idiopathic_thrombocytopenic_purpura.pdf
#   7. aortic_stenosis.pdf
#   8. preeclampsia_and_eclampsia.pdf
#   9. sezary_syndrome.pdf
#   10. mucopolysaccharidosis_type_1.pdf
#   11. atrioventricular_canal.pdf
#   12. adrenogenital_syndrome.pdf
#   13. idiopathic_thrombocytopenic_purpura.pdf
#   14. type_2_diabetes_mellitus.pdf
#   15. multiple_myeloma.pdf
#   16. bradyarrhythmias_and_conduction_disorders.pdf
#   17. secondary_glaucoma.pdf
#   18. chronic_ischemia_of_the_lower_extremities.pdf
#   19. pulmonary_hypertension.pdf
#   20. chronic_ischemia_of_the_lower_extremities.pdf
# [RERANK] 20 documents
# Reranked 5 documents
#   1. pulmonary_hypertension.pdf
#   2. mucopolysaccharidosis_type_2.pdf
#   3. idiopathic_thrombocytopenic_purpura.pdf
#   4. type_2_diabetes_mellitus.pdf
#   5. preeclampsia_and_eclampsia.pdf
#
# [CONTEXT] Preparing context from 5 documents
# Context prepared (4977 chars)
# [GENERATE] Generating answer...
# Generated 102 words
# QUERY: Какие антигипертензивные препараты рекомендуются в качестве первой линии для пациента с впервые диагностированной артериальной гипертензией II степени и отсутствием сопутствующих заболеваний?
#
#
# RETRIEVED DOCUMENTS (5):
#
# 1. pulmonary_hypertension.pdf (score: 0.1000)
#    Лекарственная терапия у пациентов с ЛГ включает средства поддерживающей терапии
# (оральные антикоагулянты (АТХ антитромботические средств а), диуретики, сердечные
# гликозиды, оксигенотерапия) и ЛАГ -с...
#
#
# 2. mucopolysaccharidosis_type_2.pdf (score: 0.2500)
#    .
# Уровень убедительности рекомендаций C (уровень достоверности доказательств – 5)
# Комментарий: рекомендовано участие мультидисциплинарной команды в ведении
# сердечной недостаточности у пациентов с М...
#
#
# 3. idiopathic_thrombocytopenic_purpura.pdf (score: 0.2500)
#    3.2.2 Терапия пациентов с впервые диагностированной ИТП 2-й линии
#  Спленэктомия при впервые диагностированной ИТП рекомендуется пациентам при
# отсутствии/потере ответа на терапию 1-ой линии для дост...
#
#
# 4. type_2_diabetes_mellitus.pdf (score: 0.1250)
#    Указания на
# высокий риск АССЗ
# (возраст ≥55 лет с
# наличием стеноза
# коронарных артерий
# или каротидных
# артерий или артерий
# нижних конечностей
# или гипертрофия
# ЛЖ)
# - эффективны в
# качестве первич...
#
#
# 5. preeclampsia_and_eclampsia.pdf (score: 0.2000)
#    антигипертензивной терапии улучшает исходы беременности . Антигипертензивные
# лекарства должны быть уменьшены в дозах или отменены, если ДАД снижается до <80 мм
# рт. ст. .
#
#  При проведении антигипе...
#
# ANSWER:
# Для пациента с впервые диагностированной артериальной гипертензией II степени и отсутствием сопутствующих заболеваний первоочередной терапией могут быть препараты из следующих групп:
#
# 1. **Антигипертензивные средства для лечения артериальной гипертонии (АТХ-группа СО9АА):**
#    - Атенолол
#    - Барбиталины (например, трилорицин)
#    - Дигидроэтиламиновые гликозиды (например, карведилол)
#    - Фенилбутазон
#
# 2. **Антигипертензивные средства для лечения эректильной дисфункции (АТХ-группа C08DA01):**
#    - Алфлутоп
#    - Дапаглифлокс
#
# 3. **Антигипертензивные средства для лечения легочной артериальной гипертонии (АТХ-группа C03DA01):**
#    - Агонисты рецепторов ПЦ (например, алфлутоп)
#
# Однако, для точного выбора лекарства и его дозировки рекомендуется консультироваться с врачом. В документе нет подробного перечня препаратов первой линии для пациентов с артериальной гипертензией II степени без сопутствующих заболеваний.
#
# ============================================================
